# %%
from indexing import carry_backtest
import yaml

# %%
m = carry_backtest("configs.yml")

# %%
m.mainBacktester()

# %%
m.mainPerformanceAnalysis()
# Out:
# /Users/kingf.wong/Development/CandidateProject_USS/indexing.py:155: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   port_df.rolling(126).apply(dd).plot(ax=ax4, legend=False)
#             port_mthd1  port_mthd2  port_mthd3  port_mthd4
# 2000-12-31         NaN         NaN         NaN         NaN
# 2001-12-31   -0.694489   -0.824368   -1.716894   -1.804758
# 2002-12-31   -3.128161   -4.060111    1.301898   -4.036434
# 2003-12-31   -0.217168   -1.276818    2.439768   -0.866164
# 2004-12-31    2.022705    1.199574    3.562603    1.457666
# 2005-12-31   -0.088537   -0.382834   -1.525562    1.150315
# 2006-12-31    1.062570    1.478544   -2.419640   -4.283884
# 2007-12-31   -1.093082   -0.028117    1.582622   -2.622301
# ...
